# %%
import torch
import torch.nn as nn 
import torch.optim as optim

import torchvision
import torchvision.daatasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       3 import torch.optim as optim
#       5 import torchvision
# ----> 6 import torchvision.daatasets
#
# ModuleNotFoundError: No module named 'torchvision.daatasets'
